# %% [markdown]
# <a href="https://colab.research.google.com/github/koshaantala/IndustriesClimateChange/blob/main/ClimateIndustries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q plotly pandas numpy scikit-learn kagglehub

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import kagglehub
import os
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go

# %%
# Download dataset from Kaggle
path = kagglehub.dataset_download("alamshihab075/greenhouse-dataset")
# Out:
# Using Colab cache for faster access to the 'greenhouse-dataset' dataset.

# %%
df = pd.read_csv(f"{path}/SupplyChainGHGEmissionFactors_v1.3.0_NAICS_CO2e_USD2022.csv")

df.columns = df.columns.str.strip().str.replace(" ", "_")

df.rename(columns={
    "2017_NAICS_Code": "NAICS_Code",
    "2017_NAICS_Title": "Industry",
    "Supply_Chain_Emission_Factors_without_Margins": "SEF",
    "Margins_of_Supply_Chain_Emission_Factors": "MEF",
    "Supply_Chain_Emission_Factors_with_Margins": "Total_Emission_Factor"
}, inplace=True)

df = df.dropna(subset=["Total_Emission_Factor"])
df["Total_Emission_Factor"] = pd.to_numeric(df["Total_Emission_Factor"], errors="coerce")
df = df.dropna(subset=["Total_Emission_Factor"])

print("Cleaned data shape:", df.shape)
df.head()
# Out:
# Cleaned data shape: (1016, 8)
#    NAICS_Code                          Industry       GHG  \
# 0      111110                   Soybean Farming  All GHGs
# 1      111120  Oilseed (except Soybean) Farming  All GHGs
# 2      111130          Dry Pea and Bean Farming  All GHGs
# 3      111140                     Wheat Farming  All GHGs
# 4      111150                      Corn Farming  All GHGs
#
#                                 Unit    SEF    MEF  Total_Emission_Factor  \
# 0  kg CO2e/2022 USD, purchaser price  0.488  0.044                  0.532
# 1  kg CO2e/2022 USD, purchaser price  0.488  0.044                  0.532
# 2  kg CO2e/2022 USD, purchaser price  0.809  0.040                  0.848
# 3  kg CO2e/2022 USD, purchaser price  0.809  0.040                  0.848
# 4  kg CO2e/2022 USD, purchaser price  0.809  0.040                  0.848
#
#   Reference_USEEIO_Code
# 0                1111A0
# 1                1111A0
# 2                1111B0
# 3                1111B0
# 4                1111B0

# %%
import plotly.express as px

# Sort industries by emission factor for clearer visualization
df_sorted = df_clean.sort_values("Total_Emission_Factor", ascending=False)

# Create the heatmap
fig = px.imshow(
    [df_sorted["Total_Emission_Factor"]],
    labels=dict(x="Industry", color="CO₂e / USD"),
    x=df_sorted["Industry"],
    color_continuous_scale="YlOrRd"
)

fig.update_layout(
    title="Heatmap of Total Emission Factors by Industry, Current",
    xaxis_title="Industry",
    yaxis_visible=False,
    height=600,
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6f8c568a-afe5-4544-b964-3737753cf53f" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f8c568a-afe5-4544-b964-3737753cf53f")) {                    Plotly.newPlot(                        "6f8c568a-afe5-4544-b964-3737753cf53f",                        [{"coloraxis":"coloraxis","name":"0","x":["Cement Manufacturing","Beef Cattle Ranching and Farming","Cattle Feedlots","Dual-Purpose Cattle Ranching and Farming","Dairy Cattle and Milk Production","Gypsum Product Manufacturing","Lime Manufacturing","Pipeline Transportation of Natural Gas","Pipeline Transportation of Refined Petroleum Products","Pipeline Transportation of Crude Oil","All Other Pipeline Transportation","Industrial Gas Manufacturing","Cyclic Crude, Intermediate, and Gum and Wood Chemical Manufacturing","Ethyl Alcohol Manufacturing","All Other Basic Organic Chemical Manufacturing","Phosphatic Fertilizer Manufacturing","Nitrogenous Fertilizer Manufacturing","Fertilizer (Mixing Only) Manufacturing","Shellfish Farming","Sheep Farming","Fur-Bearing Animal and Rabbit Production","Other Aquaculture","Horses and Other Equine Production","Apiculture","Finfish Farming and Fish Hatcheries","Goat Farming","Hog and Pig Farming","All Other Animal Production","Asphalt Paving Mixture and Block Manufacturing","Meat Processed from Carcasses","Rendering and Meat Byproduct Processing","Animal (except Poultry) Slaughtering","Plastics Material and Resin Manufacturing","Alumina Refining and Primary Aluminum Production","Other Basic Inorganic Chemical Manufacturing","Pulp Mills","Wet Corn Milling","Other Waste Collection","Other Nonhazardous Waste Treatment and Disposal","Remediation Services","Septic Tank and Related Services","Materials Recovery Facilities","Solid Waste Combustors and Incinerators","Solid Waste Landfill","All Other Miscellaneous Waste Management Services","Hazardous Waste Collection","Solid Waste Collection","Hazardous Waste Treatment and Disposal","Cheese Manufacturing","Synthetic Rubber Manufacturing","Artificial and Synthetic Fibers and Filaments Manufacturing","Dry Pea and Bean Farming","Oilseed and Grain Combination Farming","Wheat Farming","All Other Grain Farming","Corn Farming","Rice Farming","Bituminous Coal Underground Mining","Bituminous Coal and Lignite Surface Mining","Anthracite Mining","Paperboard Mills","Coastal and Great Lakes Freight Transportation","Deep Sea Freight Transportation","Deep Sea Passenger Transportation","Inland Water Passenger Transportation","Inland Water Freight Transportation","Coastal and Great Lakes Passenger Transportation","Petrochemical Manufacturing","Fluid Milk Manufacturing","Creamery Butter Manufacturing","Iron and Steel Mills and Ferroalloy Manufacturing","All Other Miscellaneous Nonmetallic Mineral Product Manufacturing","Rice Milling","Flour Milling","Malt Manufacturing","Cotton Farming","Sugar Beet Farming","Tobacco Farming","All Other Miscellaneous Crop Farming","Sugarcane Farming","Hay Farming","Peanut Farming","Other Aluminum Rolling, Drawing, and Extruding","Aluminum Sheet, Plate, and Foil Manufacturing","Fiber, Yarn, and Thread Mills","Newsprint Mills","Paper (except Newsprint) Mills","Nonscheduled Chartered Freight Air Transportation","Nonscheduled Chartered Passenger Air Transportation","Scheduled Passenger Air Transportation","Other Nonscheduled Air Transportation","Scheduled Freight Air Transportation","Dry, Condensed, and Evaporated Dairy Product Manufacturing","Other Vegetable (except Potato) and Melon Farming","Potato Farming","Asphalt Shingle and Coating Materials Manufacturing","Ready-Mix Concrete Manufacturing","Glass Container Manufacturing","Flat Glass Manufacturing","Other Pressed and Blown Glass and  ...

# %%
# Simulated growth from 2017 → 2030
years = np.arange(2017, 2031)
growth_rate = np.random.uniform(0.01, 0.05, len(df))

df["Predicted_2030_Emission_Factor"] = df["Total_Emission_Factor"] * (1 + growth_rate)**13

# Basic regression for average trend
X = np.array([2017, 2022, 2030]).reshape(-1, 1)
y = np.array([df["Total_Emission_Factor"].mean(),
               df["Total_Emission_Factor"].mean() * 1.15,
               df["Total_Emission_Factor"].mean() * 1.25])

model = LinearRegression()
model.fit(X, y)
pred_2030 = model.predict(np.array([[2030]]))[0]

print(f"Average Emission Factor, Predicted 2030: {pred_2030:.3f} kg CO₂e / USD")
# Out:
# Average Emission Factor, Predicted 2030: 0.356 kg CO₂e / USD

# %%
fig = px.bar(
    df.sort_values("Predicted_2030_Emission_Factor", ascending=False).head(20),
    x="Industry",
    y="Predicted_2030_Emission_Factor",
    title="Forecasted Emission Factors (2030) — Top 20 Industries",
    color="Predicted_2030_Emission_Factor",
    color_continuous_scale="YlOrRd"
)
fig.update_layout(xaxis_tickangle=-45, template="plotly_white")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="adbab4ea-8c1a-40fb-adb8-8657eae513d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("adbab4ea-8c1a-40fb-adb8-8657eae513d2")) {                    Plotly.newPlot(                        "adbab4ea-8c1a-40fb-adb8-8657eae513d2",                        [{"alignmentgroup":"True","hovertemplate":"Industry=%{x}\u003cbr\u003ePredicted_2030_Emission_Factor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[6.697012012046889,5.376231611292887,3.6706338975477224,3.5213183808279744,2.859075910186496,2.62717147107824,2.5453330082920376,2.2856989294717573,2.1587880910236774,2.0978301813984133,2.0470328893940244,2.037799207372567,2.0320675012309466,2.009751522953914,2.0064184459131837,1.9881710037043239,1.9756900367340058,1.9570721143233054,1.8495768307541693,1.8469036973640403],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cement Manufacturing","Dual-Purpose Cattle Ranching and Farming","Cattle Feedlots","Beef Cattle Ranching and Farming","Gypsum Product Manufacturing","Dairy Cattle and Milk Production","Pipeline Transportation of Refined Petroleum Products","Pipeline Transportation of Natural Gas","Industrial Gas Manufacturing","Ethyl Alcohol Manufacturing","Phosphatic Fertilizer Manufacturing","Lime Manufacturing","Sheep Farming","Hog and Pig Farming","All Other Pipeline Transportation","Asphalt Paving Mixture and Block Manufacturing","Nitrogenous Fertilizer Manufacturing","Pipeline Transportation of Crude Oil","Hazardous Waste Treatment and Disposal","Horses and Other Equine Production"],"xaxis":"x","y":[6.697012012046889,5.376231611292887,3.6706338975477224,3.5213183808279744,2.859075910186496,2.62717147107824,2.5453330082920376,2.2856989294717573,2.1587880910236774,2.0978301813984133,2.0470328893940244,2.037799207372567,2.0320675012309466,2.009751522953914,2.0064184459131837,1.9881710037043239,1.9756900367340058,1.9570721143233054,1.8495768307541693,1.8469036973640403],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorsca ...
